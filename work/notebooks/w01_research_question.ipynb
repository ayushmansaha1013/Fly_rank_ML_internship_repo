# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/ayushmansaha1013/Fly_rank_ML_internship_repo/blob/main/work/notebooks/w01_research_question.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# *Name your lane — Refresh / Content Opportunity Scoring
#
#  describe your own question - I am choosing Refresh / Content Opportunity Scoring. This lane fits a content-prioritization problem where the goal is to rank existing pages by how likely they are to benefit from a refresh, so the team can focus effort on the pages with the highest expected return.
#
# This is a good lane because content performance is not evenly distributed, and a simple manual review is too slow when there are many pages to evaluate. A scoring model can combine signals like traffic decline, ranking position, business value, and effort required into one priority list.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# *What decision does your work improve? Who acts on it? What does a wrong recommendation cost?*
#
# *decision* - Decision: Which existing content pages should be refreshed first, and which should wait or be skipped?
#
# *Who acts on it*: An SEO/content team, editor, or growth marketer acts on the ranking by updating the highest-priority pages.
#
# *Cost of a wrong recommendation*: Refreshing a low-value page wastes time and budget, while missing a high-opportunity page can mean continued traffic loss, weaker rankings, and lower conversions

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# *Load the starter CSV below and show 2-3 real numbers that make your lane look worth the next 7 weeks.*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# *Write what your work will be able to say (observed, directional, decision-support) — and what it never will (causal proof, 'predicting Google').*
#
# This project can support observed analysis, directional insights, and practical decision-making. It can identify pages that appear to have higher refresh potential and rank them for action. It cannot establish causal proof that a refresh will definitely improve outcomes, and it cannot predict Google’s future behavior with certainty.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [✅] Every section above is filled — markdown thinking AND the code that backs it
# - [✅] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [✅] No client names, URLs, or private queries anywhere
# - [✅] My claims use careful words: observed, measured, directional, decision-support
# - [✅] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
